# %%
# References:
# https://text-processing.com/demo/sentiment/

## Sentiment Analysis, can check if word is positive or negative

# Functions
import math, glob, os, ntpath
from collections import defaultdict

def checkIfInSentimentList(word, list_):
    if word in list_:
        print("The word is in the list!")
    else:
        print("The word is not in the list!")
        
def preprocess(s, case = "L"):
    if case == "L":
        s = s.lower()
    elif case == "U":
        s = s.upper()
    return s

def tokenize(s, tokenize_char=None):
    punctuations = "—-,.?!;:\n\t"
    s = [t.strip(punctuations) for t in s.split(tokenize_char)]
    s = [t for t in s if t != '']
    return s

def removeNewLine(s, tokenize_char=None):
    punctuations = "\n"
    s.strip(punctuations)
    return s

def fileToList(file):
    with open(file) as f:
        text = tokenize(preprocess(f.read()))
        return text
    
def path_leaf(path):
    head, tail = ntpath.split(path)
    return tail or ntpath.basename(head)
        
        
# Data
corpus_path = "/Users/jordanchisam/Desktop/CSE457A/InfoVisualization/JordanChisam_a3/englishfairytales/corpus/*.txt"
positive_words = "/Users/jordanchisam/Desktop/CSE457A/InfoVisualization/JordanChisam_a3/englishfairytales/positive-words.txt"
negative_words = "/Users/jordanchisam/Desktop/CSE457A/InfoVisualization/JordanChisam_a3/englishfairytales/negative-words.txt"
pos_words = fileToList(positive_words)
neg_words = fileToList(negative_words)


# boole = False
# with open(path+positive_words) as f:
#     lines = f.read().splitlines()
#     if "happy" in lines:
#         boole = True
#     print(lines)
    
# print(boole)

    


files = glob.glob(corpus_path)
word_count = 0
positive = 0
negative = 0
neutral = 0
count = 0
arr = []
d = {}
for f in files:
    with open(f) as f:
        first_line = f.readline()
        text = f.read()
        text = tokenize(preprocess(text))
        for word in text:  
            word_count = word_count + 1
            if word in pos_words:
                positive = positive + 1
            elif word in neg_words:
                negative = negative + 1

        wc = positive + negative
        name = removeNewLine(first_line)
        positive_score = round((positive/(positive+negative))*100,2)
        negative_score = round((negative/(positive+negative))*100,2)
        sentiment_score = round((positive-negative)/(positive+negative)*100,2)
        d = {
            "title": name.strip('\n'),
            "positive": positive,
            "negative": negative,
            "wc_pn": wc,
            "positive_score": positive_score,
            "negative_score": negative_score,
            "sentiment_score": sentiment_score,
            "total_wc": word_count
        }
        arr.append(d)
        count = count + 1;
        print(name)
        print("Word Count", wc)
        print("Pos: " , positive, "           ", round((positive/wc)*100,2),"%")
        print("Neg: " , negative, "          ", round((negative/wc)*100,2),"%")
        print("Positive Score: " , round((positive/(positive+negative))*100,2),"%")
        print("Negative Score: " , round((negative/(positive+negative))*100,2),"%")
        print("Sentiment Score: " , round((positive-negative)/(positive+negative)*100,2))
        positive = 0
        negative = 0
        wc = 0
        word_count = 0
        print("------------------------------------")
        

print (arr)

import csv
csv_columns = ['title','positive','negative','wc_pn','positive_score','negative_score','sentiment_score','total_wc']
csv_file = "/Users/jordanchisam/Desktop/CSE457A/InfoVisualization/JordanChisam_a3/data/sentiment_analysis.csv"
# try:
#     with open(csv_file, 'w') as csvfile:
#         writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
#         writer.writeheader()
#         for data in d:
#             writer.writerow(d)
# except IOError:
#     print("I/O error") 
    
    
# with open(csv_file, 'w') as f:
#     dict_writer = csv.writer(f)
#     dict_writer.writerow(csv_columns)
# #     dict_writer.writerows(d)
#     for d_ in arr:
#         dict_writer.writerow(d_)


jsonFile = "/Users/jordanchisam/Desktop/CSE457A/InfoVisualization/JordanChisam_a3/data/englishfairytales_sentiment_analysis.json"
import json
 
json = json.dumps(arr)
f = open(jsonFile, "w")
f.write(json)
f.close()
# Out:
# TITTY MOUSE AND TATTY MOUSE
#
# Word Count 36
# Pos:  5             13.89 %
# Neg:  31            86.11 %
# Positive Score:  13.89 %
# Negative Score:  86.11 %
# Sentiment Score:  -72.22
# ------------------------------------
# MASTER OF ALL MASTERS
#
# Word Count 6
# Pos:  5             83.33 %
# Neg:  1            16.67 %
# Positive Score:  83.33 %
# Negative Score:  16.67 %
# Sentiment Score:  66.67
# ------------------------------------
# FAIRY OINTMENT
#
# Word Count 40
# Pos:  23             57.5 %
# Neg:  17            42.5 %
# Positive Score:  57.5 %
# Negative Score:  42.5 %
# Sentiment Score:  15.0
# ------------------------------------
# THE RED ETTIN
#
# Word Count 73
# Pos:  37             50.68 %
# Neg:  36            49.32 %
# Positive Score:  50.68 %
# Negative Score:  49.32 %
# Sentiment Score:  1.37
# ------------------------------------
# EARL MAR'S DAUGHTER
#
# Word Count 44
# Pos:  30             68.18 %
# Neg:  14            31.82 %
# Positive Score:  68.18 %
# Negative Score:  31.82 %
# Sentiment Score:  36.36
# ------------------------------------
# THE CAULD LAD OF HILTON
#
# Word Count 18
# Pos:  8             44.44 %
# Neg:  10            55.56 %
# Positive Score:  44.44 %
# Negative Score:  55.56 %
# Sentiment Score:  -11.11
# ------------------------------------
# THE MAGPIE'S NEST
#
# Word Count 17
# Pos:  7             41.18 %
# Neg:  10            58.82 %
# Positive Score:  41.18 %
# Negative Score:  58.82 %
# Sentiment Score:  -17.65
# ------------------------------------
# JACK HANNAFORD
#
# Word Count 26
# Pos:  13             50.0 %
# Neg:  13            50.0 %
# Positive Score:  50.0 %
# Negative Score:  50.0 %
# Sentiment Score:  0.0
# ------------------------------------
# CHILDE ROWLAND
#
# Word Count 91
# Pos:  40             43.96 %
# Neg:  51            56.04 %
# Positive Score:  43.96 %
# Negative Score:  56.04 %
# Sentiment Score:  -12.09
# ------------------------------------
# JACK AND HIS GOLDEN SNUFF-BOX
#
# Word Count 152
# Pos:  96             63.16 %
# Neg:  56            36.84 %
# Positive Score:  63.16 %
# Negative Score:  36.84 %
# Sentiment Score:  26.32
# ------------------------------------
# THE ROSE-TREE
#
# Word Count 46
# Pos:  24             52.17 %
# Neg:  22            47.83 %
# Positive Score:  52.17 %
# Negative Score:  47.83 %
# Sentiment Score:  4.35
# ------------------------------------
# CAP O' RUSHES
#
# Word Count 64
# Pos:  50             78.12 %
# Neg:  14            21.88 %
# Positive Score:  78.12 %
# Negative Score:  21.88 %
# Sentiment Score:  56.25
# ------------------------------------
# HOW JACK WENT TO SEEK HIS FORTUNE
#
# Word Count 19
# Pos:  5             26.32 %
# Neg:  14            73.68 %
# Positive Score:  26.32 %
# Negative Score:  73.68 %
# Sentiment Score:  -47.37
# ------------------------------------
# THE ASS, THE TABLE, AND THE STICK
#
# Word Count 47
# Pos:  25             53.19 %
# Neg:  22            46.81 %
# Positive Score:  53.19 %
# Negative Score:  46.81 %
# Sentiment Score:  6.38
# ------------------------------------
# WHITTINGTON AND HIS CAT
#
# Word Count 232
# Pos:  113             48.71 %
# Neg:  119            51.29 %
# Positive Score:  48.71 %
# Negative Score:  51.29 %
# Sentiment Score:  -2.59
# ------------------------------------
# THE FISH AND THE RING
#
# Word Count 43
# Pos:  27             62.79 %
# Neg:  16            37.21 %
# Positive Score:  62.79 %
# Negative Score:  37.21 %
# Sentiment Score:  25.58
# ------------------------------------
# LAZY JACK
#
# Word Count 39
# Pos:  15             38.46 %
# Neg:  24            61.54 %
# Positive Score:  38.46 %
# Negative Score:  61.54 %
# Sentiment Score:  -23.08
# ------------------------------------
# THE LAIDLY WORM OF SPINDLESTON HEUGH
#
# Word Count 56
# Pos:  25             44.64 %
# Neg:  31            55.36 %
# Positive Score:  44.64 %
# Negative Score:  55.36 %
# Sentiment Score:  -10.71
# ------------------------------------
# THE HISTORY OF TOM THUMB
#
# Word Count 119
# Pos:  45             37.82 %
# Neg:  74            62.18 %
# Positive Score:  37.82 %
# Negative Score:  62.18 %
# Sentiment Score:  -24.37
# ------------------------------------
# THE OLD WOMAN AND HER PIG
#
# Word Count 45
# Pos:  1             2.22 %
# Neg:  44            97.78 %
# Positive Score:  2.22 %
# Negative Score:  97.78 %
# Sentiment Score:  -95.56
# ------------------------------------
# MOLLY WHUPPIE
#
# Word Count 56
# Pos:  25             44.64 %
# Neg:  31            55.36 %
# Positive Score:  44.64 %
# Negative Score:  55.36 %
# Sentiment Score:  -10.71
# ------------------------------------
# MR. VINEGAR
#
# Word Count 69
# Pos:  39             56.52 %
# Neg:  30            43.48 %
# Positive Score:  56.52 %
# Negative Score:  43.48 %
# Sentiment Score:  13.04
# ------------------------------------
# THE CAT AND THE MOUSE
#
# Word Count 8
# Pos:  0             0.0 %
# Neg:  8            100.0 %
# Positive Score:  0.0 %
# Negative Score:  100.0 %
# Sentiment Score:  -100.0
# ------------------------------------
# THE WELL OF THE WORLD'S END
#
# Word Count 57
# Pos:  40             70.18 %
# Neg:  17            29.82 %
# Positive Score:  70.18 %
# Negative Score:  29.82 %
# Sentiment Score:  40.35
# ------------------------------------
# THE STORY OF THE THREE LITTLE PIGS
#
# Word Count 68
# Pos:  18             26.47 %
# Neg:  50            73.53 %
# Positive Score:  26.47 %
# Negative Score:  73.53 %
# Sentiment Score:  -47.06
# ------------------------------------
# KATE CRACKERNUTS
#
# Word Count 49
# Pos:  26             53.06 %
# Neg:  23            46.94 %
# Positive Score:  53.06 %
# Negative Score:  46.94 %
# Sentiment Score:  6.12
# ------------------------------------
# JACK THE GIANT-KILLER
#
# Word Count 256
# Pos:  109             42.58 %
# Neg:  147            57.42 %
# Positive Score:  42.58 %
# Negative Score:  57.42 %
# Sentiment Score:  -14.84
# ------------------------------------
# THE STRANGE VISITOR
#
# Word Count 1
# Pos:  1             100.0 %
# Neg:  0            0.0 %
# Positive Score:  100.0 %
# Negative Score:  0.0 %
# Sentiment Score:  100.0
# ------------------------------------
# MR. FOX
#
# Word Count 41
# Pos:  14             34.15 %
# Neg:  27            65.85 %
# Positive Score:  34.15 %
# Negative Score:  65.85 %
# Sentiment Score:  -31.71
# ------------------------------------
# TEENY-TINY
#
# Word Count 3
# Pos:  0             0.0 %
# Neg:  3            100.0 %
# Positive Score:  0.0 %
# Negative Score:  100.0 %
# Sentiment Score:  -100.0
# ------------------------------------
# THE THREE SILLIES
#
# Word Count 50
# Pos:  18             36.0 %
# Neg:  32            64.0 %
# Positive Score:  36.0 %
# Negative Score:  64.0 %
# Sentiment Score:  -28.0
# ------------------------------------
# TOM TIT TOT
#
# Word Count 56
# Pos:  44             78.57 %
# Neg:  12            21.43 %
# Positive Score:  78.57 %
# Negative Score:  21.43 %
# Sentiment Score:  57.14
# ------------------------------------
# JACK AND THE BEANSTALK
#
# Word Count 115
# Pos:  71             61.74 %
# Neg:  44            38.26 %
# Positive Score:  61.74 %
# Negative Score:  38.26 %
# Sentiment Score:  23.48
# ------------------------------------
# THE STORY OF THE THREE BEARS
#
# Word Count 92
# Pos:  53             57.61 %
# Neg:  39            42.39 %
# Positive Score:  57.61 %
# Negative Score:  42.39 %
# Sentiment Score:  15.22
# ------------------------------------
# BINNORIE
#
# Word Count 48
# Pos:  34             70.83 %
# Neg:  14            29.17 %
# Positive Score:  70.83 %
# Negative Score:  29.17 %
# Sentiment Score:  41.67
# ------------------------------------
# JOHNNY-CAKE
#
# Word Count 13
# Pos:  9             69.23 %
# Neg:  4            30.77 %
# Positive Score:  69.23 %
# Negative Score:  30.77 %
# Sentiment Score:  38.46
# ------------------------------------
# THE THREE HEADS OF THE WELL
#
# Word Count 93
# Pos:  55             59.14 %
# Neg:  38            40.86 %
# Positive Score:  59.14 %
# Negative Score:  40.86 %
# Sentiment Score:  18.28
# ------------------------------------
# NIX NOUGHT NOTHING
#
# Word Count 79
# Pos:  44             55.7 %
# Neg:  35            44.3 %
# Positive Score:  55.7 %
# Negative Score:  44.3 %
# Sentiment Score:  11.39
# ------------------------------------
# THE MASTER AND HIS PUPIL
#
# Word Count 45
# Pos:  24             53.33 %
# Neg:  21            46.67 %
# Positive Score:  53.33 %
# Negative Score:  46.67 %
# Sentiment Score:  6.67
# ------------------------------------
# HENNY-PENNY
#
# Word Count 13
# Pos:  2             15.38 %
# Neg:  11            84.62 %
# Positive Score:  15.38 %
# Negative Score:  84.62 %
# Sentiment Score:  -69.23
# ------------------------------------
# MR. MIACCA
#
# Word Count 35
# Pos:  16             45.71 %
# Neg:  19            54.29 %
# Positive Score:  45.71 %
# Negative Score:  54.29 %
# Sentiment Score:  -8.57
# ------------------------------------
# MOUSE AND MOUSER
#
# Word Count 35
# Pos:  34             97.14 %
# Neg:  1            2.86 %
# Positive Score:  97.14 %
# Negative Score:  2.86 %
# Sentiment Score:  94.29
# ------------------------------------
# THE GOLDEN ARM
#
# Word Count 25
# Pos:  16             64.0 %
# Neg:  9            36.0 %
# Positive Score:  64.0 %
# Negative Score:  36.0 %
# Sentiment Score:  28.0
# ------------------------------------
# [{'title': 'TITTY MOUSE AND TATTY MOUSE', 'positive': 5, 'negative': 31, 'wc_pn': 36, 'positive_score': 13.89, 'negative_score': 86.11, 'sentiment_score': -72.22, 'total_wc': 753}, {'title': 'MASTER OF ALL MASTERS', 'positive': 5, 'negative': 1, 'wc_pn': 6, 'positive_score': 83.33, 'negative_score': 16.67, 'sentiment_score': 66.67, 'total_wc': 293}, {'title': 'FAIRY OINTMENT', 'positive': 23, 'negative': 17, 'wc_pn': 40, 'positive_score': 57.5, 'negative_score': 42.5, 'sentiment_score': 15.0, 'total_wc': 804}, {'title': 'THE RED ETTIN', 'positive': 37, 'negative': 36, 'wc_pn': 73, 'positive_score': 50.68, 'negative_score': 49.32, 'sentiment_score': 1.37, 'total_wc': 1680}, {'title': "EARL MAR'S DAUGHTER", 'positive': 30, 'negative': 14, 'wc_pn': 44, 'positive_score': 68.18, 'negative_score': 31.82, 'sentiment_score': 36.36, 'total_wc': 1089}, {'title': 'THE CAULD LAD OF HILTON', 'positive': 8, 'negative': 10, 'wc_pn': 18, 'positive_score': 44.44, 'negative_score': 55.56, 'sentiment_score': -11.11, 'total_wc': 428}, {'title': "THE MAGPIE'S NEST", 'positive': 7, 'negative': 10, 'wc_pn': 17, 'positive_score': 41.18, 'negative_score': 58.82, 'sentiment_score': -17.65, 'total_wc': 409}, {'title': 'JACK HANNAFORD', 'positive': 13, 'negative': 13, 'wc_pn': 26, 'positive_score': 50.0, 'negative_score': 50.0, 'sentiment_score': 0.0, 'total_wc': 679}, {'title': 'CHILDE ROWLAND', 'positive': 40, 'negative': 51, 'wc_pn': 91, 'positive_score': 43.96, 'negative_score': 56.04, 'sentiment_score': -12.09, 'total_wc': 1875}, {'title': 'JACK AND HIS GOLDEN SNUFF-BOX', 'positive': 96, 'negative': 56, 'wc_pn': 152, 'positive_score': 63.16, 'negative_score': 36.84, 'sentiment_score': 26.32, 'total_wc': 3550}, {'title': 'THE ROSE-TREE', 'positive': 24, 'negative': 22, 'wc_pn': 46, 'positive_score': 52.17, 'negative_score': 47.83, 'sentiment_score': 4.35, 'total_wc': 955}, {'title': "CAP O' RUSHES", 'positive': 50, 'negative': 14, 'wc_pn': 64, 'positive_score': 78.12, 'negative_score': 21.88, 'sentiment_score': 56.25, 'total_wc': 1358}, {'title': 'HOW JACK WENT TO SEEK HIS FORTUNE', 'positive': 5, 'negative': 14, 'wc_pn': 19, 'positive_score': 26.32, 'negative_score': 73.68, 'sentiment_score': -47.37, 'total_wc': 639}, {'title': 'THE ASS, THE TABLE, AND THE STICK', 'positive': 25, 'negative': 22, 'wc_pn': 47, 'positive_score': 53.19, 'negative_score': 46.81, 'sentiment_score': 6.38, 'total_wc': 1188}, {'title': 'WHITTINGTON AND HIS CAT', 'positive': 113, 'negative': 119, 'wc_pn': 232, 'positive_score': 48.71, 'negative_score': 51.29, 'sentiment_score': -2.59, 'total_wc': 3200}, {'title': 'THE FISH AND THE RING', 'positive': 27, 'negative': 16, 'wc_pn': 43, 'positive_score': 62.79, 'negative_score': 37.21, 'sentiment_score': 25.58, 'total_wc': 1188}, {'title': 'LAZY JACK', 'positive': 15, 'negative': 24, 'wc_pn': 39, 'positive_score': 38.46, 'negative_score': 61.54, 'sentiment_score': -23.08, 'total_wc': 701}, {'title': 'THE LAIDLY WORM OF SPINDLESTON HEUGH', 'positive': 25, 'negative': 31, 'wc_pn': 56, 'positive_score': 44.64, 'negative_score': 55.36, 'sentiment_score': -10.71, 'total_wc': 1278}, {'title': 'THE HISTORY OF TOM THUMB', 'positive': 45, 'negative': 74, 'wc_pn': 119, 'positive_score': 37.82, 'negative_score': 62.18, 'sentiment_score': -24.37, 'total_wc': 1873}, {'title': 'THE OLD WOMAN AND HER PIG', 'positive': 1, 'negative': 44, 'wc_pn': 45, 'positive_score': 2.22, 'negative_score': 97.78, 'sentiment_score': -95.56, 'total_wc': 687}, {'title': 'MOLLY WHUPPIE', 'positive': 25, 'negative': 31, 'wc_pn': 56, 'positive_score': 44.64, 'negative_score': 55.36, 'sentiment_score': -10.71, 'total_wc': 1389}, {'title': 'MR. VINEGAR', 'positive': 39, 'negative': 30, 'wc_pn': 69, 'positive_score': 56.52, 'negative_score': 43.48, 'sentiment_score': 13.04, 'total_wc': 1115}, {'title': 'THE CAT AND THE MOUSE', 'positive': 0, 'negative': 8, 'wc_pn': 8, 'positive_score': 0.0, 'negative_score': 100.0, 'sentiment_score': -100.0, 'total_wc': 389}, {'title':  ...
